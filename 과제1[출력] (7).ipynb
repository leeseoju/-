# %% [markdown]
# # 1. 파일 제목을 빅숙타 1주차 과제_이름 으로 바꿔주세요

# %% [markdown]
# # [사칙연산]
# ## 2. 변수 a는 자신의 출생년도, b는 자신이 좋아하는 숫자, c는 태어난 달로 대입한 후 (a+b)/c 한 값을 구하시오.

# %% [markdown]
# # [PRINT 함수]
# ## 3. 다음 코드가 올바르게 출력되도록 수정하시오.

# %%
print(that feeling when)
# Out:
#   Cell In[1], line 1
#     print(that feeling when)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# ## 4. Who's there? 을 print 함수로 출력하시오

# %% [markdown]
# ## 5. "너는 최고야"라고 응원했다. 를 print 함수로 출력하시오.

# %% [markdown]
# ## 6. 숙명여대 최고 맛집은?달볶이?포돈?긴자료코?못 고르겠다. 를 두 가지 방법으로 print 함수로 출력하시오.

# %% [markdown]
# ## 7. 청바지 삼행시 (줄바꿈) 청춘은 (탭) 바로 (탭) 지금부터 를 print 함수로 출력하시오. (줄바꿈과 탭은 강의 자료에서 나온 방법대로 해주세요.)

# %% [markdown]
# ## 8.
# ## 빅숙타 파이팅
# ## 빅숙타 파이팅
#
# ## 을 print 함수로 출력하시오. (줄바꿈만 사용하면 안됨!)

# %% [markdown]
# ## 9. 다음 변수들을 이용하여 '안녕하세요 제 이름은 [이름]이고, 취미는 [취미]이고, 좋아하는 노래는 [좋아하는 노래]입니다.' 형식의 문장을 print 함수로 출력하시오.

# %%
name = 자신의 이름
hobby = 자신의 취미
song = 자신이 좋아하는 노래
